# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjanaPushpita/Image-conversion/blob/main/rgb_gray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage import data, color

# %%
# Import the data and color modules from Scikit image. The first module provides example images, and the second, color transformation functions.
# Load the rocket image.
# Convert the RGB-3 rocket image to grayscale.
# Import the modules from skimage
from skimage import data, color

def show_image(image, title='Image', cmap_type='gray'):
  plt.imshow(image, cmap=cmap_type)
  plt.title(title)
  plt.axis('off')
  plt.show()
# Load the rocket image
rocket = data.rocket()

# Convert the image to grayscale
gray_scaled_rocket = color.rgb2gray(rocket)

# Show the original image
show_image(rocket, 'Original RGB image')

# Show the grayscale image
show_image(gray_scaled_rocket, 'Grayscale image')

# %%
# Flip the image vertically
flipped_image = np.flipud(gray_scaled_rocket)

# Show the original image
show_image(gray_scaled_rocket, 'Grayscale image')

# Show the flipped image
show_image(flipped_image, 'Flipped image')

# %%
# Flip the previous image horizontally
flipped_image_horizontally = np.fliplr(flipped_image)

# Show the horizontal flipped image
show_image(flipped_image_horizontally, 'Horizontal flipped image')

# %%
# Obtain the red channel using slicing.
# Plot the histogram and bins in a range of 256. Don't forget .ravel() for the color channel.
# Obtain the red channel
rocket = data.rocket()
red_channel = rocket[:, :, 0]

# Plot the red histogram with bins in a range of 256
plt.hist(red_channel.ravel(), bins=256)

# Set title and show
plt.title('Red Histogram')
plt.show()

# %%
# Import the otsu threshold function.
# Turn the image to grayscale.
# Obtain the optimal threshold value of the image.
# Apply thresholding to the image.

# Import the otsu threshold function
from skimage.filters  import threshold_otsu

# Make the image grayscale using rgb2gray
gray_scaled_rocket = color.rgb2gray(rocket)

# Obtain the optimal threshold value with otsu
thresh = threshold_otsu(gray_scaled_rocket)

# Apply thresholding to the image
binary = gray_scaled_rocket > thresh

# Show the image
show_image(binary, 'Binary image')

# %%
# Import the otsu threshold function, obtain the optimal global thresh value of the image, and apply global thresholding.

# Import the otsu threshold function
from skimage.filters import threshold_otsu

# Obtain the optimal otsu global thresh value
global_thresh = threshold_otsu(gray_scaled_rocket)

# Obtain the binary image by applying global thresholding
binary_global = gray_scaled_rocket > global_thresh

# Show the binary image
show_image(binary_global, 'Binary image')

# %%
# Import the local threshold function, set block size to 35, obtain the local thresh value, and apply local thresholding.
# Import the local threshold function
from skimage.filters import threshold_local

# Set the block size to 35
block_size = 35

# Obtain the optimal local thresholding
local_thresh = threshold_local(gray_scaled_rocket, block_size, offset=10)

# Obtain the binary image by applying local thresholding
binary_local = gray_scaled_rocket > local_thresh

# Show the binary image
show_image(binary_local, 'Local thresholding')

# %%
# Import the rgb to gray convertor function
from skimage.color import rgb2gray
from skimage.filters import try_all_threshold

# Obtain the grayscale image
grayscale = rgb2gray(rocket)


# Use the try all method on the resulting grayscale image
fig, ax = try_all_threshold(grayscale, verbose=False)

# Show the resulting plots
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjanaPushpita/Image-conversion/blob/main/canny.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import io, transform
import matplotlib.pyplot as plt
import numpy as np
from skimage.color import rgb2gray
from skimage.transform import rotate, rescale
from skimage import data, measure
from skimage import filters
from skimage.filters import threshold_otsu
from skimage.feature  import canny

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %%
I = io.imread("grapefruit.jpg")

# Convert image to grayscale
grapefruit = rgb2gray(I)

# Apply canny edge detector
canny_edges = canny(grapefruit)


io.imshow(I)
plt.axis("off")
plt.title("original")
plt.show()

io.imshow(canny_edges)
plt.axis("off")
plt.title("canny")
plt.show()


# Apply canny edge detector with a sigma of 1.8
edges_1_8 = canny(grapefruit, sigma=1.8)

# Apply canny edge detector with a sigma of 2.2
edges_2_2 = canny(grapefruit, sigma=2.2)

io.imshow(edges_1_8)
plt.axis("off")
plt.title("edges_1_8")
plt.show()

io.imshow(edges_2_2)
plt.axis("off")
plt.title("edges_2_2")
plt.show()
# Out:
# <ipython-input-14-20175f6da258>:10: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I)
# <ipython-input-14-20175f6da258>:15: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(canny_edges)
# <ipython-input-14-20175f6da258>:27: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(edges_1_8)
# <ipython-input-14-20175f6da258>:32: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(edges_2_2)
